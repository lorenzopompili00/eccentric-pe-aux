# %%
from eccentric_pe_aux.convert_posterior_egw import convert_to_egw

# %%
q = 1.5
chi1 = 0.0
chi2 = 0.0
eccentricity = 0.5
rel_anomaly = 0.0
Mtot = 50.0
f_min = 10.0
deltaT = 1.0 / 4096.0
f_ref = 20.0

for approximant in ["TEOBResumSDALI", "SEOBNRv5EHM", "SEOBNRv6EHM"]:
    e_gw, mean_anomaly = convert_to_egw(
        q=q,
        chi1=chi1,
        chi2=chi2,
        eccentricity=eccentricity,
        rel_anomaly=rel_anomaly,
        Mtot=Mtot,
        f_min=f_min,
        deltaT=deltaT,
        f_ref=f_ref,
        approximant=approximant,
    )

    print(f"approximant = {approximant}")
    print(f"e_gw = {e_gw}")
    print(f"mean_anomaly = {mean_anomaly}")
    print("\n")
